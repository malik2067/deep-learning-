# %%
import tensorflow as tf
import numpy as np

# %%
npz = np.load('creditcard_fraud_validation.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('creditcard_fraud_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

npz = np.load('creditcard_fraud_test.npz')
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %%
# Set the input and output sizes
input_size = 10
output_size = 2
# Use same hidden layer size for both hidden layers. Not a necessity.
hidden_layer_size = 50
model = tf.keras.Sequential([
    # tf.keras.layers.Dense is basically implementing: output = activation(dot(input, weight) + bias)
    # it takes several arguments, but the most important ones for us are the hidden_layer_size and the activation function
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    # the final layer is no different, we just make sure to activate it with softmax
    tf.keras.layers.Dense(output_size, activation='softmax') # output layer
])
### Choose the optimizer and the loss function
# we define the optimizer we'd like to use, 
# the loss function, 
# and the metrics we are interested in obtaining at each iteration
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

### Training
# That's where we train the model we have built.

# set the batch size
batch_size = 100

# set a maximum number of training epochs
max_epochs = 100

early_stopping = tf.keras.callbacks.EarlyStopping(patience=5)
model.fit(train_inputs, # train inputs
          train_targets, # train targets
          batch_size=batch_size, # batch size
          epochs=max_epochs, # epochs that we will train for (assuming early stopping doesn't kick in)
          callbacks=[early_stopping],
          validation_data=(validation_inputs, validation_targets), # validation data
          verbose = 2 
          )
# Out:
# Epoch 1/100
# 1/1 - 0s - loss: 0.6169 - accuracy: 0.6429 - val_loss: 0.5773 - val_accuracy: 0.7347
# Epoch 2/100
# 1/1 - 0s - loss: 0.5773 - accuracy: 0.7347 - val_loss: 0.5416 - val_accuracy: 0.8163
# Epoch 3/100
# 1/1 - 0s - loss: 0.5416 - accuracy: 0.8163 - val_loss: 0.5094 - val_accuracy: 0.8776
# Epoch 4/100
# 1/1 - 0s - loss: 0.5094 - accuracy: 0.8776 - val_loss: 0.4803 - val_accuracy: 0.8878
# Epoch 5/100
# 1/1 - 0s - loss: 0.4803 - accuracy: 0.8878 - val_loss: 0.4541 - val_accuracy: 0.8878
# Epoch 6/100
# 1/1 - 0s - loss: 0.4541 - accuracy: 0.8878 - val_loss: 0.4302 - val_accuracy: 0.8878
# Epoch 7/100
# 1/1 - 0s - loss: 0.4302 - accuracy: 0.8878 - val_loss: 0.4085 - val_accuracy: 0.8878
# Epoch 8/100
# 1/1 - 0s - loss: 0.4085 - accuracy: 0.8878 - val_loss: 0.3887 - val_accuracy: 0.8980
# Epoch 9/100
# 1/1 - 0s - loss: 0.3887 - accuracy: 0.8980 - val_loss: 0.3705 - val_accuracy: 0.9082
# Epoch 10/100
# 1/1 - 0s - loss: 0.3705 - accuracy: 0.9082 - val_loss: 0.3539 - val_accuracy: 0.9082
# Epoch 11/100
# 1/1 - 0s - loss: 0.3539 - accuracy: 0.9082 - val_loss: 0.3386 - val_accuracy: 0.9082
# Epoch 12/100
# 1/1 - 0s - loss: 0.3386 - accuracy: 0.9082 - val_loss: 0.3246 - val_accuracy: 0.9184
# Epoch 13/100
# 1/1 - 0s - loss: 0.3246 - accuracy: 0.9184 - val_loss: 0.3118 - val_accuracy: 0.9184
# Epoch 14/100
# 1/1 - 0s - loss: 0.3118 - accuracy: 0.9184 - val_loss: 0.3002 - val_accuracy: 0.9184
# Epoch 15/100
# 1/1 - 0s - loss: 0.3002 - accuracy: 0.9184 - val_loss: 0.2894 - val_accuracy: 0.9184
# Epoch 16/100
# 1/1 - 0s - loss: 0.2894 - accuracy: 0.9184 - val_loss: 0.2794 - val_accuracy: 0.9184
# Epoch 17/100
# 1/1 - 0s - loss: 0.2794 - accuracy: 0.9184 - val_loss: 0.2701 - val_accuracy: 0.9184
# Epoch 18/100
# 1/1 - 0s - loss: 0.2701 - accuracy: 0.9184 - val_loss: 0.2613 - val_accuracy: 0.9286
# Epoch 19/100
# 1/1 - 0s - loss: 0.2613 - accuracy: 0.9286 - val_loss: 0.2531 - val_accuracy: 0.9286
# Epoch 20/100
# 1/1 - 0s - loss: 0.2531 - accuracy: 0.9286 - val_loss: 0.2455 - val_accuracy: 0.9286
# Epoch 21/100
# 1/1 - 0s - loss: 0.2455 - accuracy: 0.9286 - val_loss: 0.2383 - val_accuracy: 0.9286
# Epoch 22/100
# 1/1 - 0s - loss: 0.2383 - accuracy: 0.9286 - val_loss: 0.2315 - val_accuracy: 0.9286
# Epoch 23/100
# 1/1 - 0s - loss: 0.2315 - accuracy: 0.9286 - val_loss: 0.2249 - val_accuracy: 0.9286
# Epoch 24/100
# 1/1 - 0s - loss: 0.2249 - accuracy: 0.9286 - val_loss: 0.2187 - val_accuracy: 0.9286
# Epoch 25/100
# 1/1 - 0s - loss: 0.2187 - accuracy: 0.9286 - val_loss: 0.2127 - val_accuracy: 0.9286
# Epoch 26/100
# 1/1 - 0s - loss: 0.2127 - accuracy: 0.9286 - val_loss: 0.2070 - val_accuracy: 0.9286
# Epoch 27/100
# 1/1 - 0s - loss: 0.2070 - accuracy: 0.9286 - val_loss: 0.2014 - val_accuracy: 0.9286
# Epoch 28/100
# 1/1 - 0s - loss: 0.2014 - accuracy: 0.9286 - val_loss: 0.1960 - val_accuracy: 0.9286
# Epoch 29/100
# 1/1 - 0s - loss: 0.1960 - accuracy: 0.9286 - val_loss: 0.1907 - val_accuracy: 0.9286
# Epoch 30/100
# 1/1 - 0s - loss: 0.1907 - accuracy: 0.9286 - val_loss: 0.1854 - val_accuracy: 0.9286
# Epoch 31/100
# 1/1 - 0s - loss: 0.1854 - accuracy: 0.9286 - val_loss: 0.1802 - val_accuracy: 0.9388
# Epoch 32/100
# 1/1 - 0s - loss: 0.1802 - accuracy: 0.9388 - val_loss: 0.1751 - val_accuracy: 0.9388
# Epoch 33/100
# 1/1 - 0s - loss: 0.1751 - accuracy: 0.9388 - val_loss: 0.1700 - val_accuracy: 0.9490
# Epoch 34/100
# 1/1 - 0s - loss: 0.1700 - accuracy: 0.9490 - val_loss: 0.1650 - val_accuracy: 0.9490
# Epoch 35/100
# 1/1 - 0s - loss: 0.1650 - accuracy: 0.9490 - val_loss: 0.1600 - val_accuracy: 0.9490
# Epoch 36/100
# 1/1 - 0s - loss: 0.1600 - accuracy: 0.9490 - val_loss: 0.1553 - val_accuracy: 0.9490
# Epoch 37/100
# 1/1 - 0s - loss: 0.1553 - accuracy: 0.9490 - val_loss: 0.1506 - val_accuracy: 0.9490
# Epoch 38/100
# 1/1 - 0s - loss: 0.1506 - accuracy: 0.9490 - val_loss: 0.1459 - val_accuracy: 0.9490
# Epoch 39/100
# 1/1 - 0s - loss: 0.1459 - accuracy: 0.9490 - val_loss: 0.1414 - val_accuracy: 0.9490
# Epoch 40/100
# 1/1 - 0s - loss: 0.1414 - accuracy: 0.9490 - val_loss: 0.1370 - val_accuracy: 0.9592
# Epoch 41/100
# 1/1 - 0s - loss: 0.1370 - accuracy: 0.9592 - val_loss: 0.1327 - val_accuracy: 0.9592
# Epoch 42/100
# 1/1 - 0s - loss: 0.1327 - accuracy: 0.9592 - val_loss: 0.1286 - val_accuracy: 0.9592
# Epoch 43/100
# 1/1 - 0s - loss: 0.1286 - accuracy: 0.9592 - val_loss: 0.1245 - val_accuracy: 0.9592
# Epoch 44/100
# 1/1 - 0s - loss: 0.1245 - accuracy: 0.9592 - val_loss: 0.1206 - val_accuracy: 0.9592
# Epoch 45/100
# 1/1 - 0s - loss: 0.1206 - accuracy: 0.9592 - val_loss: 0.1166 - val_accuracy: 0.9592
# Epoch 46/100
# 1/1 - 0s - loss: 0.1166 - accuracy: 0.9592 - val_loss: 0.1127 - val_accuracy: 0.9592
# Epoch 47/100
# 1/1 - 0s - loss: 0.1127 - accuracy: 0.9592 - val_loss: 0.1088 - val_accuracy: 0.9592
# Epoch 48/100
# 1/1 - 0s - loss: 0.1088 - accuracy: 0.9592 - val_loss: 0.1051 - val_accuracy: 0.9592
# Epoch 49/100
# 1/1 - 0s - loss: 0.1051 - accuracy: 0.9592 - val_loss: 0.1015 - val_accuracy: 0.9694
# Epoch 50/100
# 1/1 - 0s - loss: 0.1015 - accuracy: 0.9694 - val_loss: 0.0979 - val_accuracy: 0.9694
# Epoch 51/100
# 1/1 - 0s - loss: 0.0979 - accuracy: 0.9694 - val_loss: 0.0944 - val_accuracy: 0.9694
# Epoch 52/100
# 1/1 - 0s - loss: 0.0944 - accuracy: 0.9694 - val_loss: 0.0909 - val_accuracy: 0.9694
# Epoch 53/100
# 1/1 - 0s - loss: 0.0909 - accuracy: 0.9694 - val_loss: 0.0875 - val_accuracy: 0.9694
# Epoch 54/100
# 1/1 - 0s - loss: 0.0875 - accuracy: 0.9694 - val_loss: 0.0841 - val_accuracy: 0.9694
# Epoch 55/100
# 1/1 - 0s - loss: 0.0841 - accuracy: 0.9694 - val_loss: 0.0809 - val_accuracy: 0.9694
# Epoch 56/100
# 1/1 - 0s - loss: 0.0809 - accuracy: 0.9694 - val_loss: 0.0777 - val_accuracy: 0.9694
# Epoch 57/100
# 1/1 - 0s - loss: 0.0777 - accuracy: 0.9694 - val_loss: 0.0746 - val_accuracy: 0.9796
# Epoch 58/100
# 1/1 - 0s - loss: 0.0746 - accuracy: 0.9796 - val_loss: 0.0715 - val_accuracy: 0.9796
# Epoch 59/100
# 1/1 - 0s - loss: 0.0715 - accuracy: 0.9796 - val_loss: 0.0685 - val_accuracy: 0.9796
# Epoch 60/100
# 1/1 - 0s - loss: 0.0685 - accuracy: 0.9796 - val_loss: 0.0656 - val_accuracy: 0.9796
# Epoch 61/100
# 1/1 - 0s - loss: 0.0656 - accuracy: 0.9796 - val_loss: 0.0628 - val_accuracy: 0.9796
# Epoch 62/100
# 1/1 - 0s - loss: 0.0628 - accuracy: 0.9796 - val_loss: 0.0601 - val_accuracy: 0.9796
# Epoch 63/100
# 1/1 - 0s - loss: 0.0601 - accuracy: 0.9796 - val_loss: 0.0574 - val_accuracy: 0.9898
# Epoch 64/100
# 1/1 - 0s - loss: 0.0574 - accuracy: 0.9898 - val_loss: 0.0549 - val_accuracy: 0.9898
# Epoch 65/100
# 1/1 - 0s - loss: 0.0549 - accuracy: 0.9898 - val_loss: 0.0525 - val_accuracy: 0.9898
# Epoch 66/100
# 1/1 - 0s - loss: 0.0525 - accuracy: 0.9898 - val_loss: 0.0501 - val_accuracy: 0.9898
# Epoch 67/100
# 1/1 - 0s - loss: 0.0501 - accuracy: 0.9898 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 68/100
# 1/1 - 0s - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 69/100
# 1/1 - 0s - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 1.0000
# Epoch 70/100
# 1/1 - 0s - loss: 0.0437 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 71/100
# 1/1 - 0s - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 1.0000
# Epoch 72/100
# 1/1 - 0s - loss: 0.0397 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 1.0000
# Epoch 73/100
# 1/1 - 0s - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 1.0000
# Epoch 74/100
# 1/1 - 0s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 1.0000
# Epoch 75/100
# 1/1 - 0s - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 76/100
# 1/1 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 77/100
# 1/1 - 0s - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 1.0000
# Epoch 78/100
# 1/1 - 0s - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 79/100
# 1/1 - 0s - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 80/100
# 1/1 - 0s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 81/100
# 1/1 - 0s - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 82/100
# 1/1 - 0s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 83/100
# 1/1 - 0s - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 84/100
# 1/1 - 0s - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 85/100
# 1/1 - 0s - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 86/100
# 1/1 - 0s - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 87/100
# 1/1 - 0s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 88/100
# 1/1 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 89/100
# 1/1 - 0s - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 90/100
# 1/1 - 0s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 91/100
# 1/1 - 0s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 92/100
# 1/1 - 0s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 93/100
# 1/1 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 94/100
# 1/1 - 0s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 95/100
# 1/1 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 96/100
# 1/1 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 97/100
# 1/1 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 98/100
# 1/1 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 99/100
# 1/1 - 0s - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 100/100
# 1/1 - 0s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000

# %%
test_loss, test_accuracy=model.evaluate(test_inputs,test_targets)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0653 - accuracy: 0.9899

# %%
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.07. Test accuracy: 98.99%
